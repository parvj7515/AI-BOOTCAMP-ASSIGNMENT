# %%
import random
numbers = [random.randint(1, 100) for i in range(10)]

print("Random Numbers:")
print(numbers)

print("\nEven Numbers:")
for num in numbers:
    if num % 2 == 0:
        print(num)
# Out:
# Random Numbers:
# [55, 24, 6, 59, 76, 34, 29, 25, 42, 84]
#
# Even Numbers:
# 24
# 6
# 76
# 34
# 42
# 84

# %%
text = "Artificial Intelligence is Amazing"

reverse_string = text[::-1]

print("Original String:")
print(text)

print("\nReversed String:")
print(reverse_string)

reverse_words = " ".join(text.split()[::-1])

print("\nWords Reversed:")
print(reverse_words)
# Out:
# Original String:
# Artificial Intelligence is Amazing
#
# Reversed String:
# gnizamA si ecnegilletnI laicifitrA
#
# Words Reversed:
# Amazing is Intelligence Artificial
