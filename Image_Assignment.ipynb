# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-5.0.0.93-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=2 in D:\miniconda3\Lib\site-packages (from opencv-python) (2.5.1)
# Downloading opencv_python-5.0.0.93-cp37-abi3-win_amd64.whl (44.0 MB)
#    ---------------------------------------- 0.0/44.0 MB ? eta -:--:--
#     --------------------------------------- 0.8/44.0 MB 5.0 MB/s eta 0:00:09
#    -- ------------------------------------- 2.4/44.0 MB 5.7 MB/s eta 0:00:08
#    --- ------------------------------------ 3.4/44.0 MB 5.3 MB/s eta 0:00:08
#    --- ------------------------------------ 3.9/44.0 MB 5.3 MB/s eta 0:00:08
#    ----- ---------------------------------- 5.5/44.0 MB 5.0 MB/s eta 0:00:08
#    ----- ---------------------------------- 6.3/44.0 MB 4.7 MB/s eta 0:00:09
#    ------ --------------------------------- 7.3/44.0 MB 4.8 MB/s eta 0:00:08
#    ------- -------------------------------- 8.7/44.0 MB 4.9 MB/s eta 0:00:08
#    -------- ------------------------------- 9.7/44.0 MB 5.0 MB/s eta 0:00:07
#    ---------- ----------------------------- 11.3/44.0 MB 5.2 MB/s eta 0:00:07
#    ----------- ---------------------------- 12.6/44.0 MB 5.3 MB/s eta 0:00:06
#    ------------ --------------------------- 13.6/44.0 MB 5.3 MB/s eta 0:00:06
#    ------------- -------------------------- 14.9/44.0 MB 5.3 MB/s eta 0:00:06
#    -------------- ------------------------- 16.3/44.0 MB 5.3 MB/s eta 0:00:06
#    ---------------- ----------------------- 17.8/44.0 MB 5.4 MB/s eta 0:00:05
#    ----------------- ---------------------- 19.1/44.0 MB 5.5 MB/s eta 0:00:05
#    ------------------ --------------------- 20.4/44.0 MB 5.5 MB/s eta 0:00:05
#    -------------------- ------------------- 22.0/44.0 MB 5.6 MB/s eta 0:00:04
#    --------------------- ------------------ 23.6/44.0 MB 5.6 MB/s eta 0:00:04
#    ---------------------- ----------------- 24.9/44.0 MB 5.7 MB/s eta 0:00:04
#    ----------------------- ---------------- 26.2/44.0 MB 5.7 MB/s eta 0:00:04
#    ------------------------ --------------- 27.3/44.0 MB 5.7 MB/s eta 0:00:03
#    ------------------------- -------------- 28.6/44.0 MB 5.7 MB/s eta 0:00:03
#    -------------------------- ------------- 29.6/44.0 MB 5.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 30.9/44.0 MB 5.7 MB/s eta 0:00:03
#    ----------------------------- ---------- 32.2/44.0 MB 5.7 MB/s eta 0:00:03
#    ------------------------------ --------- 33.8/44.0 MB 5.7 MB/s eta 0:00:02
#    -------------------------------- ------- 35.4/44.0 MB 5.8 MB/s eta 0:00:02
#    --------------------------------- ------ 36.7/44.0 MB 5.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 37.7/44.0 MB 5.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 39.3/44.0 MB 5.8 MB/s eta 0:00:01
#    ------------------------------------- -- 40.9/44.0 MB 5.9 MB/s eta 0:00:01
#    -------------------------------------- - 42.2/44.0 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------  43.8/44.0 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------  43.8/44.0 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------  43.8/44.0 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------  43.8/44.0 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 44.0/44.0 MB 5.4 MB/s  0:00:08
# Installing collected packages: opencv-python
# Successfully installed opencv-python-5.0.0.93

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("nielit.jpeg")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(6,6))
plt.imshow(img_rgb)
plt.title("Original Image")
plt.axis("off")
plt.show()

# %%
resized = cv2.resize(img_rgb, (300, 300))
plt.figure(figsize=(5,5))
plt.imshow(resized)
plt.title("Resized Image (300 x 300)")
plt.axis("off")
plt.show()

# %%
flipped = cv2.flip(img_rgb, 1)
plt.figure(figsize=(6,6))
plt.imshow(flipped)
plt.title("Horizontally Flipped Image")
plt.axis("off")
plt.show()
